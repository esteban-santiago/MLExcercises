# %%
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, KBinsDiscretizer, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
import pandas as pd

df = sns.load_dataset('titanic')[['survived', 'age', 'embarked']]
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='survived'), df['survived'], test_size=0.2, 
                                                    random_state=123)

# %%
num = ['age']
cat = ['embarked']

num_transformer = Pipeline(steps=[('imputer', SimpleImputer()), 
                                  ('discritiser', KBinsDiscretizer(encode='ordinal', strategy='uniform')),
                                  ('scaler', MinMaxScaler())])

cat_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
                                  ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(transformers=[('num', num_transformer, num),
                                               ('cat', cat_transformer, cat)])

pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('classiffier', LogisticRegression(random_state=1, max_iter=10000))])

param_grid = {'preprocessor__num__imputer__strategy' : ['mean', 'median'],
              'preprocessor__num__discritiser__n_bins' : range(5,10),
              'classiffier__C' : [0.1, 10, 100],
              'classiffier__solver' : ['liblinear', 'saga']}
grid_search = GridSearchCV(
    pipe, 
    param_grid=param_grid, 
    cv=10,
    scoring='accuracy'
)

# %%
grid_search.fit(X_train, y_train)
pd.DataFrame(grid_search.cv_results_).set_index('rank_test_score')
# Out:
#                  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# rank_test_score
# 51                    0.006990      0.000844         0.003401        0.000467
# 51                    0.007276      0.000717         0.003618        0.000439
# 22                    0.006681      0.000917         0.003450        0.000697
# 22                    0.007391      0.000992         0.003514        0.000654
# 55                    0.007643      0.000899         0.003749        0.000459
# 55                    0.009437      0.001261         0.004640        0.000717
# 21                    0.008194      0.000727         0.003976        0.000293
# 34                    0.008289      0.000490         0.003887        0.000276
# 39                    0.007427      0.000512         0.003567        0.000266
# 39                    0.008981      0.001063         0.004478        0.000642
# 51                    0.009352      0.000180         0.004114        0.000289
# 51                    0.009193      0.000293         0.003848        0.000136
# 22                    0.009245      0.000381         0.004064        0.000391
# 22                    0.009840      0.000336         0.003957        0.000202
# 55                    0.009162      0.000396         0.004074        0.000540
# 55                    0.009625      0.000262         0.003944        0.000182
# 59                    0.009168      0.000302         0.003931        0.000158
# 60                    0.009560      0.000414         0.004053        0.000315
# 41                    0.009163      0.000430         0.003852        0.000199
# 41                    0.010054      0.001006         0.004147        0.000404
# 41                    0.007849      0.000251         0.003819        0.000325
# 41                    0.007904      0.000244         0.003769        0.000346
# 9                     0.007801      0.000385         0.003714        0.000144
# 9                     0.007973      0.000299         0.003699        0.000182
# 22                    0.007678      0.000212         0.003686        0.000147
# 22                    0.007948      0.000177         0.003740        0.000189
# 1                     0.007809      0.000309         0.003768        0.000202
# 5                     0.008269      0.000715         0.003969        0.000390
# 34                    0.007746      0.000232         0.003713        0.000201
# 34                    0.008147      0.000243         0.003815        0.000348
# 41                    0.012416      0.000346         0.004027        0.000312
# 41                    0.011447      0.001312         0.003417        0.000601
# 9                     0.010758      0.000523         0.002997        0.000161
# 9                     0.010891      0.000628         0.003151        0.000264
# 22                    0.010217      0.000648         0.003103        0.000351
# 22                    0.010343      0.000920         0.002858        0.000186
# 1                     0.010683      0.000553         0.003044        0.000289
# 5                     0.010374      0.000769         0.003110        0.000555
# 34                    0.010619      0.000482         0.003287        0.000550
# 34                    0.010710      0.000733         0.002977        0.000336
# 41                    0.006582      0.000456         0.003559        0.000996
# 41                    0.007445      0.000726         0.003299        0.000268
# 9                     0.006505      0.000375         0.002998        0.000241
# 9                     0.006883      0.000621         0.003088        0.000316
# 22                    0.006359      0.000410         0.002896        0.000129
# 22                    0.006634      0.000432         0.003016        0.000224
# 1                     0.006376      0.000383         0.003016        0.000252
# 5                     0.006544      0.000601         0.002951        0.000225
# 9                     0.006381      0.000382         0.003072        0.000287
# 9                     0.006687      0.000689         0.003561        0.000838
# 41                    0.018886      0.001987         0.003204        0.000502
# 41                    0.019035      0.001449         0.003468        0.000414
# 9                     0.019919      0.000950         0.003114        0.000285
# 9                     0.020397      0.001001         0.003215        0.000389
# 22                    0.019028      0.001034         0.003097        0.000259
# 22                    0.019040      0.001057         0.003082        0.000314
# 1                     0.019550      0.000961         0.003247        0.000241
# 5                     0.019200      0.001121         0.002892        0.000185
# 9                     0.019918      0.000725         0.003281        0.000538
# 9                     0.020286      0.000750         0.003163        0.000364
#
#                 param_classiffier__C param_classiffier__solver  \
# rank_test_score
# 51                               0.1                 liblinear
# 51                               0.1                 liblinear
# 22                               0.1                 liblinear
# 22                               0.1                 liblinear
# 55                               0.1                 liblinear
# 55                               0.1                 liblinear
# 21                               0.1                 liblinear
# 34                               0.1                 liblinear
# 39                               0.1                 liblinear
# 39                               0.1                 liblinear
# 51                               0.1                      saga
# 51                               0.1                      saga
# 22                               0.1                      saga
# 22                               0.1                      saga
# 55                               0.1                      saga
# 55                               0.1                      saga
# 59                               0.1                      saga
# 60                               0.1                      saga
# 41                               0.1                      saga
# 41                               0.1                      saga
# 41                                10                 liblinear
# 41                                10                 liblinear
# 9                                 10                 liblinear
# 9                                 10                 liblinear
# 22                                10                 liblinear
# 22                                10                 liblinear
# 1                                 10                 liblinear
# 5                                 10                 liblinear
# 34                                10                 liblinear
# 34                                10                 liblinear
# 41                                10                      saga
# 41                                10                      saga
# 9                                 10                      saga
# 9                                 10                      saga
# 22                                10                      saga
# 22                                10                      saga
# 1                                 10                      saga
# 5                                 10                      saga
# 34                                10                      saga
# 34                                10                      saga
# 41                               100                 liblinear
# 41                               100                 liblinear
# 9                                100                 liblinear
# 9                                100                 liblinear
# 22                               100                 liblinear
# 22                               100                 liblinear
# 1                                100                 liblinear
# 5                                100                 liblinear
# 9                                100                 liblinear
# 9                                100                 liblinear
# 41                               100                      saga
# 41                               100                      saga
# 9                                100                      saga
# 9                                100                      saga
# 22                               100                      saga
# 22                               100                      saga
# 1                                100                      saga
# 5                                100                      saga
# 9                                100                      saga
# 9                                100                      saga
#
#                 param_preprocessor__num__discritiser__n_bins  \
# rank_test_score
# 51                                                         5
# 51                                                         5
# 22                                                         6
# 22                                                         6
# 55                                                         7
# 55                                                         7
# 21                                                         8
# 34                                                         8
# 39                                                         9
# 39                                                         9
# 51                                                         5
# 51                                                         5
# 22                                                         6
# 22                                                         6
# 55                                                         7
# 55                                                         7
# 59                                                         8
# 60                                                         8
# 41                                                         9
# 41                                                         9
# 41                                                         5
# 41                                                         5
# 9                                                          6
# 9                                                          6
# 22                                                         7
# 22                                                         7
# 1                                                          8
# 5                                                          8
# 34                                                         9
# 34                                                         9
# 41                                                         5
# 41                                                         5
# 9                                                          6
# 9                                                          6
# 22                                                         7
# 22                                                         7
# 1                                                          8
# 5                                                          8
# 34                                                         9
# 34                                                         9
# 41                                                         5
# 41                                                         5
# 9                                                          6
# 9                                                          6
# 22                                                         7
# 22                                                         7
# 1                                                          8
# 5                                                          8
# 9                                                          9
# 9                                                          9
# 41                                                         5
# 41                                                         5
# 9                                                          6
# 9                                                          6
# 22                                                         7
# 22                                                         7
# 1                                                          8
# 5                                                          8
# 9                                                          9
# 9                                                          9
#
#                 param_preprocessor__num__imputer__strategy  \
# rank_test_score
# 51                                                    mean
# 51                                                  median
# 22                                                    mean
# 22                                                  median
# 55                                                    mean
# 55                                                  median
# 21                                                    mean
# 34                                                  median
# 39                                                    mean
# 39                                                  median
# 51                                                    mean
# 51                                                  median
# 22                                                    mean
# 22                                                  median
# 55                                                    mean
# 55                                                  median
# 59                                                    mean
# 60                                                  median
# 41                                                    mean
# 41                                                  median
# 41                                                    mean
# 41                                                  median
# 9                                                     mean
# 9                                                   median
# 22                                                    mean
# 22                                                  median
# 1                                                     mean
# 5                                                   median
# 34                                                    mean
# 34                                                  median
# 41                                                    mean
# 41                                                  median
# 9                                                     mean
# 9                                                   median
# 22                                                    mean
# 22                                                  median
# 1                                                     mean
# 5                                                   median
# 34                                                    mean
# 34                                                  median
# 41                                                    mean
# 41                                                  median
# 9                                                     mean
# 9                                                   median
# 22                                                    mean
# 22                                                  median
# 1                                                     mean
# 5                                                   median
# 9                                                     mean
# 9                                                   median
# 41                                                    mean
# 41                                                  median
# 9                                                     mean
# 9                                                   median
# 22                                                    mean
# 22                                                  median
# 1                                                     mean
# 5                                                   median
# 9                                                     mean
# 9                                                   median
#
#                                                             params  \
# rank_test_score
# 51               {'classiffier__C': 0.1, 'classiffier__solver':...
# 51               {'classiffier__C': 0.1, 'classiffier__solver':...
# 22               {'classiffier__C': 0.1, 'classiffier__solver':...
# 22               {'classiffier__C': 0.1, 'classiffier__solver':...
# 55               {'classiffier__C': 0.1, 'classiffier__solver':...
# 55               {'classiffier__C': 0.1, 'classiffier__solver':...
# 21               {'classiffier__C': 0.1, 'classiffier__solver':...
# 34               {'classiffier__C': 0.1, 'classiffier__solver':...
# 39               {'classiffier__C': 0.1, 'classiffier__solver':...
# 39               {'classiffier__C': 0.1, 'classiffier__solver':...
# 51               {'classiffier__C': 0.1, 'classiffier__solver':...
# 51               {'classiffier__C': 0.1, 'classiffier__solver':...
# 22               {'classiffier__C': 0.1, 'classiffier__solver':...
# 22               {'classiffier__C': 0.1, 'classiffier__solver':...
# 55               {'classiffier__C': 0.1, 'classiffier__solver':...
# 55               {'classiffier__C': 0.1, 'classiffier__solver':...
# 59               {'classiffier__C': 0.1, 'classiffier__solver':...
# 60               {'classiffier__C': 0.1, 'classiffier__solver':...
# 41               {'classiffier__C': 0.1, 'classiffier__solver':...
# 41               {'classiffier__C': 0.1, 'classiffier__solver':...
# 41               {'classiffier__C': 10, 'classiffier__solver': ...
# 41               {'classiffier__C': 10, 'classiffier__solver': ...
# 9                {'classiffier__C': 10, 'classiffier__solver': ...
# 9                {'classiffier__C': 10, 'classiffier__solver': ...
# 22               {'classiffier__C': 10, 'classiffier__solver': ...
# 22               {'classiffier__C': 10, 'classiffier__solver': ...
# 1                {'classiffier__C': 10, 'classiffier__solver': ...
# 5                {'classiffier__C': 10, 'classiffier__solver': ...
# 34               {'classiffier__C': 10, 'classiffier__solver': ...
# 34               {'classiffier__C': 10, 'classiffier__solver': ...
# 41               {'classiffier__C': 10, 'classiffier__solver': ...
# 41               {'classiffier__C': 10, 'classiffier__solver': ...
# 9                {'classiffier__C': 10, 'classiffier__solver': ...
# 9                {'classiffier__C': 10, 'classiffier__solver': ...
# 22               {'classiffier__C': 10, 'classiffier__solver': ...
# 22               {'classiffier__C': 10, 'classiffier__solver': ...
# 1                {'classiffier__C': 10, 'classiffier__solver': ...
# 5                {'classiffier__C': 10, 'classiffier__solver': ...
# 34               {'classiffier__C': 10, 'classiffier__solver': ...
# 34               {'classiffier__C': 10, 'classiffier__solver': ...
# 41               {'classiffier__C': 100, 'classiffier__solver':...
# 41               {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 22               {'classiffier__C': 100, 'classiffier__solver':...
# 22               {'classiffier__C': 100, 'classiffier__solver':...
# 1                {'classiffier__C': 100, 'classiffier__solver':...
# 5                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 41               {'classiffier__C': 100, 'classiffier__solver':...
# 41               {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 22               {'classiffier__C': 100, 'classiffier__solver':...
# 22               {'classiffier__C': 100, 'classiffier__solver':...
# 1                {'classiffier__C': 100, 'classiffier__solver':...
# 5                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
#
#                  split0_test_score  ...  split2_test_score  split3_test_score  \
# rank_test_score                     ...
# 51                        0.611111  ...           0.549296           0.661972
# 51                        0.611111  ...           0.549296           0.661972
# 22                        0.597222  ...           0.549296           0.661972
# 22                        0.597222  ...           0.549296           0.661972
# 55                        0.597222  ...           0.549296           0.661972
# 55                        0.597222  ...           0.549296           0.661972
# 21                        0.611111  ...           0.549296           0.661972
# 34                        0.611111  ...           0.549296           0.661972
# 39                        0.597222  ...           0.549296           0.676056
# 41                        0.647887           0.633803           0.549296
# 9                         0.647887           0.633803           0.577465
# 9                         0.647887           0.633803           0.577465
# 22                        0.647887           0.633803           0.563380
# 22                        0.647887           0.633803           0.563380
# 1                         0.647887           0.633803           0.577465
# 5                         0.647887           0.633803           0.563380
# 34                        0.633803           0.633803           0.563380
# 34                        0.633803           0.633803           0.563380
# 41                        0.647887           0.633803           0.549296
# 41                        0.647887           0.633803           0.549296
# 9                         0.647887           0.633803           0.577465
# 9                         0.647887           0.633803           0.577465
# 22                        0.647887           0.633803           0.563380
# 22                        0.647887           0.633803           0.563380
# 1                         0.647887           0.633803           0.577465
# 5                         0.647887           0.633803           0.563380
# 9                         0.633803           0.633803           0.577465
# 9                         0.633803           0.633803           0.577465
# 41                        0.647887           0.633803           0.549296
# 41                        0.647887           0.633803           0.549296
# 9                         0.647887           0.633803           0.577465
# 9                         0.647887           0.633803           0.577465
# 22                        0.647887           0.633803           0.563380
# 22                        0.647887           0.633803           0.563380
# 1                         0.647887           0.633803           0.577465
# 5                         0.647887           0.633803           0.563380
# 9                         0.633803           0.633803           0.577465
# 9                         0.633803           0.633803           0.577465
#
#                  mean_test_score  std_test_score
# rank_test_score
# 51                      0.617958        0.039854
# 51                      0.617958        0.039854
# 22                      0.620794        0.039170
# 22                      0.620794        0.039170
# 55                      0.616569        0.039312
# 55                      0.616569        0.039312
# 21                      0.622183        0.040065
# 34                      0.620775        0.042293
# 39                      0.619386        0.038930
# 39                      0.619386        0.038930
# 51                      0.617958        0.039854
# 51                      0.617958        0.039854
# 22                      0.620794        0.039170
# 22                      0.620794        0.039170
# 55                      0.616569        0.039312
# 55                      0.616569        0.039312
# 59                      0.615141        0.034835
# 60                      0.613732        0.037109
# 41                      0.617977        0.037596
# 41                      0.617977        0.037596
# 41                      0.617977        0.039650
# 41                      0.617977        0.039650
# 9                       0.623592        0.036584
# 9                       0.623592        0.036584
# 22                      0.620794        0.037089
# 22                      0.620794        0.037089
# 1                       0.626428        0.034824
# 5                       0.625020        0.036994
# 34                      0.620775        0.037309
# 34                      0.620775        0.037309
# 41                      0.617977        0.039650
# 41                      0.617977        0.039650
# 9                       0.623592        0.036584
# 9                       0.623592        0.036584
# 22                      0.620794        0.037089
# 22                      0.620794        0.037089
# 1                       0.626428        0.034824
# 5                       0.625020        0.036994
# 34                      0.620775        0.037309
# 34                      0.620775        0.037309
# 41                      0.617977        0.039650
# 41                      0.617977        0.039650
# 9                       0.623592        0.036584
# 9                       0.623592        0.036584
# 22                      0.620794        0.037089
# 22                      0.620794        0.037089
# 1                       0.626428        0.034824
# 5                       0.625020        0.036994
# 9                       0.623592        0.032568
# 9                       0.623592        0.032568
# 41                      0.617977        0.039650
# 41                      0.617977        0.039650
# 9                       0.623592        0.036584
# 9                       0.623592        0.036584
# 22                      0.620794        0.037089
# 22                      0.620794        0.037089
# 1                       0.626428        0.034824
# 5                       0.625020        0.036994
# 9                       0.623592        0.032568
# 9                       0.623592        0.032568
#
# [60 rows x 21 columns]
