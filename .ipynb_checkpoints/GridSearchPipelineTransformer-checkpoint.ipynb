# %%
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, KBinsDiscretizer, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
import pandas as pd

df = sns.load_dataset('titanic')[['survived', 'age', 'embarked']]
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='survived'), df['survived'], test_size=0.2, 
                                                    random_state=123)
num = ['age']
cat = ['embarked']

num_transformer = Pipeline(steps=[('imputer', SimpleImputer()), 
                                  ('discritiser', KBinsDiscretizer(encode='ordinal', strategy='uniform')),
                                  ('scaler', MinMaxScaler())])

cat_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
                                  ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(transformers=[('num', num_transformer, num),
                                               ('cat', cat_transformer, cat)])

pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('classiffier', LogisticRegression(random_state=1, max_iter=10000))])

param_grid = {'preprocessor__num__imputer__strategy' : ['mean', 'median'],
              'preprocessor__num__discritiser__n_bins' : range(5,10),
              'classiffier__C' : [0.1, 10, 100],
              'classiffier__solver' : ['liblinear', 'saga']}
grid_search = GridSearchCV(
    pipe, 
    param_grid=param_grid, 
    cv=10,
    scoring='accuracy'
)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('discritiser',
#                                                                                           KBinsDiscretizer(encode='ordinal',
#                                                                                                            strategy='uniform')),
#                                                                                          ('scaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['age']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(fill_value='missing',
#                                                                                                         strategy='constant')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['embarked'])])),
#                                        ('classiffier',
#                                         LogisticRegression(max_iter=10000,
#                                                            random_state=1))]),
#              param_grid={'classiffier__C': [0.1, 10, 100],
#                          'classiffier__solver': ['liblinear', 'saga'],
#                          'preprocessor__num__discritiser__n_bins': range(5, 10),
#                          'preprocessor__num__imputer__strategy': ['mean',
#                                                                   'median']},
#              scoring='accuracy')

# %%
pd.DataFrame(grid_search.cv_results_).set_index('rank_test_score')
# Out:
#                  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# rank_test_score
# 51                    0.007669      0.001373         0.003533        0.000499
# 51                    0.006629      0.000632         0.003007        0.000206
# 22                    0.006079      0.000298         0.002879        0.000169
# 22                    0.006519      0.000399         0.002914        0.000209
# 55                    0.006282      0.000354         0.003034        0.000117
# 55                    0.006696      0.000639         0.003086        0.000186
# 21                    0.006338      0.000746         0.003081        0.000307
# 34                    0.006374      0.000446         0.002932        0.000176
# 39                    0.006201      0.000476         0.002852        0.000089
# 39                    0.006953      0.000676         0.003202        0.000269
# 51                    0.007511      0.000832         0.003040        0.000259
# 51                    0.007569      0.000650         0.003190        0.000487
# 22                    0.007426      0.000423         0.003028        0.000210
# 22                    0.008635      0.001206         0.003688        0.000506
# 55                    0.008059      0.000733         0.003143        0.000241
# 55                    0.007703      0.000596         0.002964        0.000295
# 59                    0.007288      0.000534         0.003200        0.000462
# 60                    0.007313      0.000325         0.003147        0.000195
# 41                    0.007568      0.000687         0.003145        0.000457
# 41                    0.007395      0.000772         0.002915        0.000224
# 41                    0.006205      0.000412         0.002861        0.000119
# 41                    0.006516      0.000768         0.003031        0.000482
# 9                     0.006371      0.000276         0.003079        0.000220
# 9                     0.006620      0.000432         0.003190        0.000333
# 22                    0.006119      0.000274         0.003018        0.000249
# 22                    0.006683      0.000632         0.003060        0.000255
# 1                     0.006247      0.000278         0.003033        0.000328
# 5                     0.006773      0.000529         0.003069        0.000241
# 34                    0.006296      0.000525         0.003037        0.000278
# 34                    0.006308      0.000299         0.002904        0.000191
# 41                    0.010147      0.000455         0.003211        0.000341
# 41                    0.011436      0.001627         0.003276        0.000461
# 9                     0.011088      0.000659         0.003422        0.000396
# 9                     0.011108      0.000633         0.003276        0.000469
# 22                    0.010620      0.000877         0.003292        0.000492
# 22                    0.010401      0.000849         0.003088        0.000368
# 1                     0.010567      0.000870         0.003219        0.000342
# 5                     0.010260      0.000483         0.003052        0.000420
# 34                    0.011307      0.000993         0.003174        0.000278
# 34                    0.011436      0.001027         0.003268        0.000383
# 41                    0.006640      0.000539         0.003010        0.000207
# 41                    0.007220      0.000645         0.003276        0.000480
# 9                     0.007622      0.000873         0.003535        0.000464
# 9                     0.006607      0.000389         0.003133        0.000271
# 22                    0.006358      0.000565         0.002910        0.000184
# 22                    0.006559      0.000584         0.003036        0.000233
# 1                     0.006956      0.000812         0.003050        0.000284
# 5                     0.006881      0.000584         0.003143        0.000273
# 9                     0.006420      0.000522         0.002963        0.000195
# 9                     0.007031      0.000564         0.003034        0.000374
# 41                    0.018566      0.000688         0.003228        0.000392
# 41                    0.018406      0.001040         0.003113        0.000290
# 9                     0.019967      0.001067         0.003380        0.000329
# 9                     0.019385      0.000866         0.003208        0.000456
# 22                    0.018827      0.001007         0.003178        0.000263
# 22                    0.019073      0.000648         0.003066        0.000317
# 1                     0.019313      0.001094         0.003155        0.000315
# 5                     0.019082      0.000602         0.003096        0.000339
# 9                     0.019511      0.000701         0.003141        0.000496
# 9                     0.020263      0.001024         0.003189        0.000290
#
#                 param_classiffier__C param_classiffier__solver  \
# rank_test_score
# 51                               0.1                 liblinear
# 51                               0.1                 liblinear
# 22                               0.1                 liblinear
# 22                               0.1                 liblinear
# 55                               0.1                 liblinear
# 55                               0.1                 liblinear
# 21                               0.1                 liblinear
# 34                               0.1                 liblinear
# 39                               0.1                 liblinear
# 39                               0.1                 liblinear
# 51                               0.1                      saga
# 51                               0.1                      saga
# 22                               0.1                      saga
# 22                               0.1                      saga
# 55                               0.1                      saga
# 55                               0.1                      saga
# 59                               0.1                      saga
# 60                               0.1                      saga
# 41                               0.1                      saga
# 41                               0.1                      saga
# 41                                10                 liblinear
# 41                                10                 liblinear
# 9                                 10                 liblinear
# 9                                 10                 liblinear
# 22                                10                 liblinear
# 22                                10                 liblinear
# 1                                 10                 liblinear
# 5                                 10                 liblinear
# 34                                10                 liblinear
# 34                                10                 liblinear
# 41                                10                      saga
# 41                                10                      saga
# 9                                 10                      saga
# 9                                 10                      saga
# 22                                10                      saga
# 22                                10                      saga
# 1                                 10                      saga
# 5                                 10                      saga
# 34                                10                      saga
# 34                                10                      saga
# 41                               100                 liblinear
# 41                               100                 liblinear
# 9                                100                 liblinear
# 9                                100                 liblinear
# 22                               100                 liblinear
# 22                               100                 liblinear
# 1                                100                 liblinear
# 5                                100                 liblinear
# 9                                100                 liblinear
# 9                                100                 liblinear
# 41                               100                      saga
# 41                               100                      saga
# 9                                100                      saga
# 9                                100                      saga
# 22                               100                      saga
# 22                               100                      saga
# 1                                100                      saga
# 5                                100                      saga
# 9                                100                      saga
# 9                                100                      saga
#
#                 param_preprocessor__num__discritiser__n_bins  \
# rank_test_score
# 51                                                         5
# 51                                                         5
# 22                                                         6
# 22                                                         6
# 55                                                         7
# 55                                                         7
# 21                                                         8
# 34                                                         8
# 39                                                         9
# 39                                                         9
# 51                                                         5
# 51                                                         5
# 22                                                         6
# 22                                                         6
# 55                                                         7
# 55                                                         7
# 59                                                         8
# 60                                                         8
# 41                                                         9
# 41                                                         9
# 41                                                         5
# 41                                                         5
# 9                                                          6
# 9                                                          6
# 22                                                         7
# 22                                                         7
# 1                                                          8
# 5                                                          8
# 34                                                         9
# 34                                                         9
# 41                                                         5
# 41                                                         5
# 9                                                          6
# 9                                                          6
# 22                                                         7
# 22                                                         7
# 1                                                          8
# 5                                                          8
# 34                                                         9
# 34                                                         9
# 41                                                         5
# 41                                                         5
# 9                                                          6
# 9                                                          6
# 22                                                         7
# 22                                                         7
# 1                                                          8
# 5                                                          8
# 9                                                          9
# 9                                                          9
# 41                                                         5
# 41                                                         5
# 9                                                          6
# 9                                                          6
# 22                                                         7
# 22                                                         7
# 1                                                          8
# 5                                                          8
# 9                                                          9
# 9                                                          9
#
#                 param_preprocessor__num__imputer__strategy  \
# rank_test_score
# 51                                                    mean
# 51                                                  median
# 22                                                    mean
# 22                                                  median
# 55                                                    mean
# 55                                                  median
# 21                                                    mean
# 34                                                  median
# 39                                                    mean
# 39                                                  median
# 51                                                    mean
# 51                                                  median
# 22                                                    mean
# 22                                                  median
# 55                                                    mean
# 55                                                  median
# 59                                                    mean
# 60                                                  median
# 41                                                    mean
# 41                                                  median
# 41                                                    mean
# 41                                                  median
# 9                                                     mean
# 9                                                   median
# 22                                                    mean
# 22                                                  median
# 1                                                     mean
# 5                                                   median
# 34                                                    mean
# 34                                                  median
# 41                                                    mean
# 41                                                  median
# 9                                                     mean
# 9                                                   median
# 22                                                    mean
# 22                                                  median
# 1                                                     mean
# 5                                                   median
# 34                                                    mean
# 34                                                  median
# 41                                                    mean
# 41                                                  median
# 9                                                     mean
# 9                                                   median
# 22                                                    mean
# 22                                                  median
# 1                                                     mean
# 5                                                   median
# 9                                                     mean
# 9                                                   median
# 41                                                    mean
# 41                                                  median
# 9                                                     mean
# 9                                                   median
# 22                                                    mean
# 22                                                  median
# 1                                                     mean
# 5                                                   median
# 9                                                     mean
# 9                                                   median
#
#                                                             params  \
# rank_test_score
# 51               {'classiffier__C': 0.1, 'classiffier__solver':...
# 51               {'classiffier__C': 0.1, 'classiffier__solver':...
# 22               {'classiffier__C': 0.1, 'classiffier__solver':...
# 22               {'classiffier__C': 0.1, 'classiffier__solver':...
# 55               {'classiffier__C': 0.1, 'classiffier__solver':...
# 55               {'classiffier__C': 0.1, 'classiffier__solver':...
# 21               {'classiffier__C': 0.1, 'classiffier__solver':...
# 34               {'classiffier__C': 0.1, 'classiffier__solver':...
# 39               {'classiffier__C': 0.1, 'classiffier__solver':...
# 39               {'classiffier__C': 0.1, 'classiffier__solver':...
# 51               {'classiffier__C': 0.1, 'classiffier__solver':...
# 51               {'classiffier__C': 0.1, 'classiffier__solver':...
# 22               {'classiffier__C': 0.1, 'classiffier__solver':...
# 22               {'classiffier__C': 0.1, 'classiffier__solver':...
# 55               {'classiffier__C': 0.1, 'classiffier__solver':...
# 55               {'classiffier__C': 0.1, 'classiffier__solver':...
# 59               {'classiffier__C': 0.1, 'classiffier__solver':...
# 60               {'classiffier__C': 0.1, 'classiffier__solver':...
# 41               {'classiffier__C': 0.1, 'classiffier__solver':...
# 41               {'classiffier__C': 0.1, 'classiffier__solver':...
# 41               {'classiffier__C': 10, 'classiffier__solver': ...
# 41               {'classiffier__C': 10, 'classiffier__solver': ...
# 9                {'classiffier__C': 10, 'classiffier__solver': ...
# 9                {'classiffier__C': 10, 'classiffier__solver': ...
# 22               {'classiffier__C': 10, 'classiffier__solver': ...
# 22               {'classiffier__C': 10, 'classiffier__solver': ...
# 1                {'classiffier__C': 10, 'classiffier__solver': ...
# 5                {'classiffier__C': 10, 'classiffier__solver': ...
# 34               {'classiffier__C': 10, 'classiffier__solver': ...
# 34               {'classiffier__C': 10, 'classiffier__solver': ...
# 41               {'classiffier__C': 10, 'classiffier__solver': ...
# 41               {'classiffier__C': 10, 'classiffier__solver': ...
# 9                {'classiffier__C': 10, 'classiffier__solver': ...
# 9                {'classiffier__C': 10, 'classiffier__solver': ...
# 22               {'classiffier__C': 10, 'classiffier__solver': ...
# 22               {'classiffier__C': 10, 'classiffier__solver': ...
# 1                {'classiffier__C': 10, 'classiffier__solver': ...
# 5                {'classiffier__C': 10, 'classiffier__solver': ...
# 34               {'classiffier__C': 10, 'classiffier__solver': ...
# 34               {'classiffier__C': 10, 'classiffier__solver': ...
# 41               {'classiffier__C': 100, 'classiffier__solver':...
# 41               {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 22               {'classiffier__C': 100, 'classiffier__solver':...
# 22               {'classiffier__C': 100, 'classiffier__solver':...
# 1                {'classiffier__C': 100, 'classiffier__solver':...
# 5                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 41               {'classiffier__C': 100, 'classiffier__solver':...
# 41               {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 22               {'classiffier__C': 100, 'classiffier__solver':...
# 22               {'classiffier__C': 100, 'classiffier__solver':...
# 1                {'classiffier__C': 100, 'classiffier__solver':...
# 5                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
# 9                {'classiffier__C': 100, 'classiffier__solver':...
#
#                  split0_test_score  ...  split2_test_score  split3_test_score  \
# rank_test_score                     ...
# 51                        0.611111  ...           0.549296           0.661972
# 51                        0.611111  ...           0.549296           0.661972
