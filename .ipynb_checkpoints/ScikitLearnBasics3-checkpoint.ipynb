# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/drawndata2.csv')
X = df[['x','y']].values
y = df['z'] == 'a'

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PolynomialFeatures

# %%
pipe = Pipeline([
        ('scale', PolynomialFeatures()),
        ('model', LogisticRegression())
]);

# %%
pred = pipe.fit(X,y).predict(X)

# %%
plt.scatter(X[:,0], X[:,1], c=pred)

# %%
plt.hist(X[:,1])
# Out:
# (array([ 6., 12., 29., 25., 16., 22., 26., 29., 27., 25.]),
#  array([-15.78079527,  33.75075906,  83.28231339, 132.81386772,
#         182.34542205, 231.87697638, 281.40853071, 330.94008504,
#         380.47163937, 430.0031937 , 479.53474804]),
#  <BarContainer object of 10 artists>)
